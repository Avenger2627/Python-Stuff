# %%
# First data is MAnually cleane using Excel...

# %%
#Read Data From Movie CSV File and Read Five Valeu

import pandas as pd

movie=pd.read_csv(r"C:\Users\ASAD\Desktop\PYTHON _WORK/Analysis Using Python\Movies.csv")
movie.head(2)
# Out:
#                                 movie_title  num_critic_for_reviews  duration  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302       NaN
#
#    DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                     10.0                     855                    1000
# 1                    563.0                    1000                   40000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 0  760505847         886204.0                     4834.0
# 1  309404152         471220.0                    48350.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 0                   NaN                  3054  237000000        2009
# 1                   NaN                  1238  300000000        2007
#
#    ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0                   936.0         7.9        2009.0
# ...

# %%
movie.duration.isnull()
print


#null value with summaiton of particular column...
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: duration, dtype: bool
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: duration, dtype: bool

# %%
#Cheking Last values
movie.tail(2)
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 12                           Quantum of Solace                     403
# 13  Pirates of the Caribbean: Dead Man's Chest                     313
#
#     duration  DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 12     106.0                    395.0                     393
# 13     151.0                    563.0                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
#     Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 12                     2023.0                   1.0                  1243
# 13                    48486.0                   2.0                  1832
#
#        budget  title_year  ACTOR_2_facebook_likes  imdb_score  title_year.1
# 12  200000000        2008                   412.0         6.7        2008.0
# ...

# %%
#Finding Null Valuescusing Sum

movie.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ...

# %%
#Showing Boollean Value
movie.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# ...

# %%
#checking total summary of data
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                14 non-null     object
#  1   num_critic_for_reviews     14 non-null     int64
#  2   duration                   11 non-null     float64
#  3   DIRECTOR_facebook_likes    12 non-null     float64
#  4   actor_3_facebook_likes     14 non-null     int64
#  5   ACTOR_1_facebook_likes     14 non-null     int64
#  6   gross                      14 non-null     int64
#  7   num_voted_users            13 non-null     float64
#  8   Cast_Total_facebook_likes  12 non-null     float64
#  9   facenumber_in_poster       9 non-null      float64
#  10  num_user_for_reviews       14 non-null     int64
#  11  budget                     14 non-null     int64
#  12  title_year                 14 non-null     int64
# ...

# %%
#ginding Mean and Std valeus
movie.describe()
# Out:
#        num_critic_for_reviews    duration  DIRECTOR_facebook_likes  \
# count               14.000000   11.000000                12.000000
# mean               506.142857  150.727273              2030.500000
# std                169.069789   21.679903              6293.007685
# min                302.000000  106.000000                10.000000
# 25%                379.250000  141.000000                13.750000
# 50%                448.000000  151.000000               152.500000
# 75%                635.000000  162.500000               497.000000
# max                813.000000  183.000000             22000.000000
#
#        actor_3_facebook_likes  ACTOR_1_facebook_likes         gross  \
# count               14.000000               14.000000  1.400000e+01
# mean              5866.142857            18206.428571  3.335836e+08
# std               8289.592695            13905.214361  1.720674e+08
# min                161.000000              451.000000  7.305868e+07
# ...

# %%
movie.head(2)
# Out:
#                                 movie_title  num_critic_for_reviews  duration  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302       NaN
#
#    DIRECTOR_facebook_likes  actor_3_facebook_likes  ACTOR_1_facebook_likes  \
# 0                     10.0                     855                    1000
# 1                    563.0                    1000                   40000
#
#        gross  num_voted_users  Cast_Total_facebook_likes  \
# 0  760505847         886204.0                     4834.0
# 1  309404152         471220.0                    48350.0
#
#    facenumber_in_poster  num_user_for_reviews     budget  title_year  \
# 0                   NaN                  3054  237000000        2009
# 1                   NaN                  1238  300000000        2007
#
#    ACTOR_2_facebook_likes  imdb_score  title_year.1
# 0                   936.0         7.9        2009.0
# ...

# %%
#Display Fill null valeu with mean without inplace
movie.duration.fillna(movie['duration'].mean().round(2))
# Out:
# 0     178.00
# 1     150.73
# 2     148.00
# 3     150.73
# 4     132.00
# 5     156.00
# 6     150.73
# 7     141.00
# 8     141.00
# 9     153.00
# 10    183.00
# 11    169.00
# 12    106.00
# 13    151.00
# Name: duration, dtype: float64
# 0     178.00
# 1     150.73
# 2     148.00
# 3     150.73
# 4     132.00
# 5     156.00
# 6     150.73
# 7     141.00
# 8     141.00
# 9     153.00
# 10    183.00
# 11    169.00
# 12    106.00
# 13    151.00
# Name: duration, dtype: float64

# %%
#Adding MEan Value to Colume
movie.duration.fillna(movie['duration'].mean().round(2),inplace=True)

# %%
#movie.DIRECTOR_facebook_likes.mean().round(2)

# %%
movie.num_voted_users.mean().round(2)
# Out:
# 462157.85
# 462157.85

# %%
movie.num_voted_users.fillna(movie['num_voted_users'].mean().round(2),inplace=True)

# %%
movie.Cast_Total_facebook_likes.mean().round(2)
# Out:
# 44773.58
# 44773.58

# %%
movie.Cast_Total_facebook_likes.fillna(movie['Cast_Total_facebook_likes'].mean().round(2),inplace=True)

# %%
movie.facenumber_in_poster.mean().round(2)
# Out:
# 2.11
# 2.11

# %%
movie.facenumber_in_poster.fillna(movie['facenumber_in_poster'].mean().round(2),inplace=True)

# %%
movie.ACTOR_2_facebook_likes.mean().round(2)
# Out:
# 8455.85
# 8455.85

# %%
movie.ACTOR_2_facebook_likes.fillna(movie['ACTOR_2_facebook_likes'].mean().round(2),inplace=True)

# %%
movie.to_csv("MovieUpdated223.csv",index=False,header=True)
print("File Save Succesfully")


#NOTE:- You need to Write inplace if you want change in your file
# Out:
# File Save Succesfully
# File Save Succesfully

# %%
#displaying Result of CSV
#movie
