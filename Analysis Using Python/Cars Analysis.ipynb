# %%
#importing Cars CSV File
import pandas as pd
cars=pd.read_csv(r"C:\Users\ASAD\Desktop\PYTHON _WORK/Analysis Using Python\Cars.csv")
cars.head(6)
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  \
# 0  Acura                      MDX    SUV   Asia        All  $36,945
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337          3.5        6.0         265        17           23    4451
# 1  $21,761          2.0        4.0         200        24           31    2778
# 2  $24,647          2.4        4.0         200        22           29    3230
# 3  $30,299          3.2        6.0         270        20           28    3575
# 4  $39,014          3.5        6.0         225        18           24    3880
# ...

# %%
# Checking Info
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
#Cehcking Detail information about Cars
cars.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
#finding Mean Calue of All 
cars.mean()
# Out:
# EngineSize        3.196729
# Cylinders         5.807512
# Horsepower      215.885514
# MPG_City         20.060748
# MPG_Highway      26.843458
# Weight         3577.953271
# Wheelbase       108.154206
# Length          186.362150
# dtype: float64

# %%
#Finding Summation of Null Values in Cars Csv
cars.isnull().sum()
cars.Cylinders.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# Name: Cylinders, Length: 428, dtype: bool

# %%
cars.fillna(0,inplace=True)

# %%
cars.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172

# %%
#Finding Toltal Record in Cars and column Make
cars['Make'].count()
# Out:
# 428

# %%
#Remocing unwanted record....................................
cars[cars['Origin'].isin (['Asia','Europe'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ded55740456> in <module>
#       1 #Remocing unwanted record....................................
# ----> 2 cars[cars['Origin'].isin (['Asia','Europe'])]
#
# NameError: name 'cars' is not defined

# %%
#Finding Value whose weight is greater than 4000

cars[cars['Weight']>4000].head(6)
# Out:
#      Make                           Model    Type  Origin DriveTrain  \
# 0   Acura                             MDX     SUV    Asia        All
# 15   Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17   Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18   Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20   Audi                        RS 6 4dr  Sports  Europe      Front
# 24   Audi            A6 3.0 Avant Quattro   Wagon  Europe        All
#
#         MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 0   $36,945   $33,337          3.5        6.0         265        17
# 15  $44,240   $40,075          3.0        6.0         220        18
# 17  $49,690   $44,936          4.2        8.0         300        17
# 18  $69,190   $64,740          4.2        8.0         330        17
# 20  $84,600   $76,417          4.2        8.0         450        15
# 24  $40,840   $37,060          3.0        6.0         220        18
#
# ...

# %%
#increase value by 3 column name is MPG_City
cars['MPG_City']=cars['MPG_City'].apply(lambda x:x+3)
cars['MPG_City']
# Out:
# 0      20
# 1      27
# 2      25
# 3      23
# 4      21
#        ..
# 423    24
# 424    23
# 425    22
# 426    25
# 427    23
# Name: MPG_City, Length: 428, dtype: int64

# %%
#Adding MEan Value to PArticular Column
cars.MPG_City.fillna(cars['MPG_City'].mean().round(2),inplace=True )
cars.tail(4)
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 424  $40,083          2.3        5.0         242        23           26
# 425  $42,573          2.9        6.0         268        22           26
# 426  $24,641          1.9        4.0         170        25           29
# 427  $33,112          2.5        5.0         208        23           27
#
#      Weight  Wheelbase  Length
# 424    3450        105     186
# 425    3653        110     190
# 426    2822        101     180
# 427    3823        109     186

# %%
#finding Unique value in length

cars['Length'].unique()
# Out:
# array([189, 172, 183, 186, 197, 174, 179, 180, 192, 193, 204, 191, 159,
#        184, 176, 177, 198, 161, 187, 195, 200, 196, 207, 199, 190, 201,
#        178, 221, 219, 163, 167, 153, 188, 222, 206, 238, 169, 208, 194,
#        160, 227, 173, 168, 212, 211, 218, 230, 175, 155, 166, 162, 182,
#        181, 150, 185, 215, 143, 144, 156, 203, 158, 202, 224, 170, 154,
#        171, 165], dtype=int64)

# %%
cars['Make'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
#Group by using Make and display all mean value
cars.groupby("Make").head(20)
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
#Checking Shape of Cars DataFrame
cars.shape
# Out:
# (428, 15)
